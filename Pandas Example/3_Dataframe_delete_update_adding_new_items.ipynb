# %%
import pandas as pd

# %%
df = pd.read_csv('supermarkets.csv')
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ## to get index as a list

# %%
# setting ID as index
df = df.set_index('ID')

# %%
df.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %% [markdown]
# ## to find columns in dataframe

# %%
df.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %% [markdown]
# # for deleting .drop is used

# %%
# 1 is for column and 0 is for row
df.drop('City', 1)
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df.drop(2,0)
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %% [markdown]
# # deleting using slicing

# %%
df.drop(df.index[2:3],0) #row slicing
# Out:
#             Address           City       State Country         Name  Employees
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA      Madeira          8
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop         15
# 4      3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
df.drop(df.columns[3:],1)
# Out:
#             Address           City             State
# ID
# 1      3666 21st St  San Francisco          CA 94114
# 2    735 Dolores St  San Francisco          CA 94119
# 3       332 Hill St  San Francisco  California 94114
# 4      3995 23rd St  San Francisco          CA 94114
# 5   1056 Sanchez St  San Francisco        California
# 6   551 Alvarado St  San Francisco          CA 94114

# %%
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %% [markdown]
# # Adding a new column into the DF

# %%
df.shape
# Out:
# (6, 7)

# %%
df.shape[0]
# Out:
# 6

# %% [markdown]
# ## one way

# %%
df['continent'] = df.shape[0]*['Newyork'] 
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees continent
# ID
# 1           8   Newyork
# 2          15   Newyork
# 3          25   Newyork
# 4          10   Newyork
# 5          12   Newyork
# 6          20   Newyork

# %% [markdown]
# ## Another way

# %%
df['test'] = df['City']+df['continent']
df
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees continent                  test
# ID
# 1           8   Newyork  San FranciscoNewyork
# 2          15   Newyork  San FranciscoNewyork
# 3          25   Newyork  San FranciscoNewyork
# 4          10   Newyork  San FranciscoNewyork
# 5          12   Newyork  San FranciscoNewyork
# 6          20   Newyork  San FranciscoNewyork

# %% [markdown]
# # To add a row we have to transpose the df

# %%
df_t = df.T
df_t
# Out:
# ID                            1                     2                     3  \
# Address            3666 21st St        735 Dolores St           332 Hill St
# City              San Francisco         San Francisco         San Francisco
# State                  CA 94114              CA 94119      California 94114
# Country                     USA                   USA                   USA
# Name                    Madeira           Bready Shop           Super River
# Employees                     8                    15                    25
# continent               Newyork               Newyork               Newyork
# test       San FranciscoNewyork  San FranciscoNewyork  San FranciscoNewyork
#
# ID                            4                     5                     6
# Address            3995 23rd St       1056 Sanchez St       551 Alvarado St
# City              San Francisco         San Francisco         San Francisco
# ...

# %%
df_t['7'] = ['My address', 'my city', '1234','my country','my name',5,'newyork','mytest']
df_t
# Out:
# ID                            1                     2                     3  \
# Address            3666 21st St        735 Dolores St           332 Hill St
# City              San Francisco         San Francisco         San Francisco
# State                  CA 94114              CA 94119      California 94114
# Country                     USA                   USA                   USA
# Name                    Madeira           Bready Shop           Super River
# Employees                     8                    15                    25
# continent               Newyork               Newyork               Newyork
# test       San FranciscoNewyork  San FranciscoNewyork  San FranciscoNewyork
#
# ID                            4                     5                     6  \
# Address            3995 23rd St       1056 Sanchez St       551 Alvarado St
# City              San Francisco         San Francisco         San Francisco
# ...

# %%
df = df_t.T
df
# Out:
#             Address           City             State     Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114         USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119         USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114         USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114         USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California         USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114         USA   Richvalley
# 7        My address        my city              1234  my country      my name
#
#    Employees continent                  test
# ID
# 1          8   Newyork  San FranciscoNewyork
# 2         15   Newyork  San FranciscoNewyork
# 3         25   Newyork  San FranciscoNewyork
# 4         10   Newyork  San FranciscoNewyork
# 5         12   Newyork  San FranciscoNewyork
# 6         20   Newyork  San FranciscoNewyork
# ...
